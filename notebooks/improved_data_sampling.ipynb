# %%
# %pip install top2vec[sentence_encoders]
from top2vec import Top2Vec
# Out:
# zsh:1: no matches found: top2vec[sentence_encoders]
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from dotenv import load_dotenv
import nltk
import re
import string
nltk.download('punkt') 
load_dotenv()
home_path = os.getenv('LOCAL_ENV')
google_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/processed_google_reviews.csv')
# Out:
# [nltk_data] Downloading package punkt to /Users/mylene/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Splitting reviews up

# %%
google_reviews["Sentence Count"] = google_reviews["Text"].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
# Custom tokenization pattern excluding certain punctuation marks
pattern = r'\b\w+\b|[' + re.escape(string.punctuation.replace('.', '')) + '](?<!\.)'

# split the google reviews 
split_google_reviews = google_reviews.copy()
split_google_reviews['Sentences'] = split_google_reviews['Text'].apply(nltk.sent_tokenize)
split_google_reviews = split_google_reviews.explode('Sentences').reset_index(drop=True)

# %%
# Count words with custom tokenization pattern
split_google_reviews['Word Count'] = split_google_reviews['Sentences'].apply(lambda x: len(nltk.regexp_tokenize(x, pattern)))

# %%
pd.set_option('display.max_colwidth', None)

# %%
# Assign unique numeric ID to each review
split_google_reviews['Review ID'] = split_google_reviews.groupby('Sentences').ngroup()

split_google_reviews = split_google_reviews[split_google_reviews['Sentence Count'] > 1]

# %%
# Filter out sentences with less than 5 words
split_google_reviews = split_google_reviews[split_google_reviews['Word Count'] >= 5]

# %% [markdown]
# ### Create SpaCy pipeline

# %%
import nltk
import spacy
from spacy.util import filter_spans
from spaczz.matcher import FuzzyMatcher
from spacy import matcher
from spacy.tokens import Doc
from nltk.corpus import wordnet
from spacy.tokens import Span

nlp = spacy.blank("en")
matcher = FuzzyMatcher(nlp.vocab)

# %% [markdown]
# ### Investigate the top noisy words

# %%
documents = split_google_reviews['Sentences'].to_list()
model = Top2Vec(documents)
model.get_num_topics()
# Out:
# 2023-06-18 13:39:07,124 - top2vec - INFO - Pre-processing documents for training
# 2023-06-18 13:39:21,060 - top2vec - INFO - Creating joint document/word embedding
# 2023-06-18 13:52:21,469 - top2vec - INFO - Creating lower dimension embedding of documents
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2023-06-18 13:57:11,226 - top2vec - INFO - Finding dense areas of documents
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
#
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2023-06-18 13:57:35,911 - top2vec - INFO - Finding topics
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 4269

# %% [markdown]
# 1. Look for the top synonyms in the actual dataset.
# 2. use those most common words as a list and feed this to your synonyms function.
# 3. use this with the fuzzy matcher to remove a higher degree of noise from the dataset.

# %%
topic_words, word_scores, topic_nums = model.get_topics(4302)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 topic_words, word_scores, topic_nums = model.get_topics(4302)
#
# File ~/opt/anaconda3/envs/BachelorsProject/lib/python3.9/site-packages/top2vec/Top2Vec.py:1466, in Top2Vec.get_topics(self, num_topics, reduced)
#    1464     num_topics = len(self.topic_vectors)
#    1465 else:
# -> 1466     self._validate_num_topics(num_topics, reduced)
#    1468 return self.topic_words[0:num_topics], self.topic_word_scores[0:num_topics], np.array(range(0, num_topics))
#
# File ~/opt/anaconda3/envs/BachelorsProject/lib/python3.9/site-packages/top2vec/Top2Vec.py:892, in Top2Vec._validate_num_topics(self, num_topics, reduced)
#     890 topic_count = len(self.topic_vectors)
#     891 if num_topics > topic_count:
# --> 892     raise ValueError(f"num_topics cannot exceed the number of topics: {topic_count}.")
#
# ValueError: num_topics cannot exceed the number of topics: 4269.

# %%
print(topic_words)
# Out:
# [['helpfull' 'tidy' 'importantly' ... 'reccomend' 'recommendable' 'humor']
#  ['relaxed' 'atmosphere' 'friendly' ... 'nice' 'modest' 'sober']
#  ['sehr' 'ditto' 'halal' ... 'furthermore' 'phenomenal' 'sublime']
#  ...
#  ['slow' 'inattentive' 'disorganized' ... 'poor' 'crowded' 'gentle']
#  ['notch' 'top' 'sehr' ... 'remains' 'african' 'et']
#  ['decent' 'hop' 'reasonable' ... 'pretty' 'premium' 'basic']]

# %%
topic_words, word_scores, topic_scores, topic_nums = model.search_topics(keywords=["wheelchair"], num_topics=4302)

# %%
topic_words, word_scores, topic_scores, topic_nums = model.search_topics(keywords=["wheelchair"], num_topics=50)
for topic in topic_nums:
    model.generate_topic_wordcloud(topic)

# %%
# %pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 5.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.17.3 in /Users/mylene/opt/anaconda3/envs/BachelorsProject/lib/python3.9/site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/mylene/opt/anaconda3/envs/BachelorsProject/lib/python3.9/site-packages (from imbalanced-learn) (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/mylene/opt/anaconda3/envs/BachelorsProject/lib/python3.9/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mylene/opt/anaconda3/envs/BachelorsProject/lib/python3.9/site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/mylene/opt/anaconda3/envs/BachelorsProject/lib/python3.9/site-packages (from imbalanced-learn) (1.10.1)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
relevant_docs = []
keywords = ["toilet"]
excluded_keywords = ["credit","money","€ ","price", "cents", "cent", "charge", "€", "charging", "euros", "pay", "paid", "paying", "payed", "dirty", "filthy", "stinky", "clean", "stink", "cost"]
documents, document_scores, document_ids = model.search_documents_by_keywords(keywords=keywords, num_docs=500)

for doc, score, doc_id in zip(documents, document_scores, document_ids):
    # Convert document to lowercase and check if it contains excluded keywords
    if any(word in doc.lower() for word in excluded_keywords):
        continue  # Skip this document and move to the next one
    print(f"Document: {doc_id}, Score: {score}")
    print("-----------")
    print(doc)
    relevant_docs.append((doc_id, score, doc))
    print("-----------")
    print()
# Out:
# Document: 79940, Score: 0.3964807987213135
# -----------
# Toilets without toilet paper and soap.
# -----------
#
# Document: 29464, Score: 0.3883405923843384
# -----------
# The toilets didn't have soap or paper towels.
# -----------
#
# Document: 386279, Score: 0.37139904499053955
# -----------
# The toilet is old and leaking.
# -----------
#
# Document: 158339, Score: 0.3659678101539612
# -----------
# (Only in the hallway to the toilet).
# -----------
#
# Document: 266475, Score: 0.36508306860923767
# -----------
# The men's bathrooms had no functioning lock.
# -----------
#
# Document: 313227, Score: 0.3647236227989197
# -----------
# The male bathroom could use a lock.
# -----------
#
# Document: 453437, Score: 0.3627600073814392
# -----------
# Bathroom without soap and towels, so one can't either wash its hands.
# -----------
#
# Document: 135856, Score: 0.3621731698513031
# -----------
# Warm, cozy, toilet.
# -----------
#
# Document: 44626, Score: 0.3620632588863373
# -----------
# No toilet paper for women.
# -----------
#
# Document: 90512, Score: 0.3610458970069885
# -----------
# No soap in the bathroom either.
# -----------
#
# Document: 313036, Score: 0.35660603642463684
# -----------
# The toilet didn't have a lock.
# -----------
#
# Document: 201903, Score: 0.35598379373550415
# -----------
# I go to the bathroom and I can't find toilet paper, much less a sink to wash my hands .. That is, I wonder how it is possible …
# -----------
#
# Document: 128454, Score: 0.35471636056900024
# -----------
# Toilet unfortunately not wheelchair accessible (down …
# -----------
#
# Document: 117142, Score: 0.3542335033416748
# -----------
# Love the modern interior and Rituals soap and hand lotion in the bathrooms :)
# -----------
#
# Document: 379412, Score: 0.3528940677642822
# -----------
# and leftover toilet paper!
# -----------
#
# Document: 157765, Score: 0.35123544931411743
# -----------
# Toilet was clogged and smelly.
# -----------
#
# Document: 363930, Score: 0.347439169883728
# -----------
#  With King's Day a bad experience that as a lady you cannot go to the men's toilet because it takes too long for the ladies to empty your stoma in the toilet.
# -----------
#
# Document: 266809, Score: 0.34590959548950195
# -----------
# No soap and hand paper on the toilet …
# -----------
#
# Document: 211964, Score: 0.3437686860561371
# -----------
# Toilet paper was diffidently absorbent.
# -----------
#
# Document: 224846, Score: 0.343313068151474
# -----------
# No toilet is a downside.
# -----------
#
# Document: 461823, Score: 0.342890202999115
# -----------
#  No toilet that is accessible for the disabled anymore, also the side door / gate was not opened for wheelchair access.
# -----------
#
# Document: 265980, Score: 0.34278666973114014
# -----------
# Seen one kitchen staff washing his hands without any soap after using toilets..
# -----------
#
# Document: 358931, Score: 0.3427804112434387
# -----------
# There is no toilet!
# -----------
#
# Document: 35281, Score: 0.341844767332077
# -----------
# Unfortunately the toilet is down the stairs so not wheelchair accessible.
# -----------
#
# Document: 353, Score: 0.34170323610305786
# -----------
# No toilet paper in toilet.
# -----------
#
# Document: 482365, Score: 0.3399185240268707
# -----------
# No soap in the bathroom.
# -----------
#
# Document: 126571, Score: 0.33539092540740967
# -----------
# Nice people, and a very nice toilet.
# -----------
#
# Document: 359976, Score: 0.3351364731788635
# -----------
# Toilet was clogged and smelly.
# -----------
#
# Document: 304628, Score: 0.3347105383872986
# -----------
# The toilets where unacceptably bad for such a high end restaurant there was no soap or towels and the …
# -----------
#
# Document: 310992, Score: 0.33411094546318054
# -----------
# The toilet doors are considerably understickered.
# -----------
#
# Document: 7774, Score: 0.3325188159942627
# -----------
# Combination of bad experiences here, capped by a poor toilet experience : no toilet paper, urine on the floors, and no soap.
# -----------
#
# Document: 135585, Score: 0.3312130570411682
# -----------
# The Polish waiter said I cannot use the toilet …
# -----------
#
# Document: 27288, Score: 0.32861989736557007
# -----------
# Toilet would not be wheelchair accessible.
# -----------
#
# Document: 134600, Score: 0.32844752073287964
# -----------
# and the soap of the dan it was amazing!
# -----------
#
# Document: 22272, Score: 0.32831770181655884
# -----------
# Staff also use this toilet ... you can check what is in your food if they do not wash their hands with soap .... …
# -----------
#
# Document: 142757, Score: 0.3273043632507324
# -----------
# Beware of the sink in the men's bathroom.
# -----------
#
# Document: 209823, Score: 0.3261016607284546
# -----------
#  With King's Day a bad experience that as a lady you cannot go to the men's toilet because it takes too long for the ladies to empty your stoma in the toilet.
# -----------
#
# Document: 237848, Score: 0.32595595717430115
# -----------
# No towels in the toilet either.
# -----------
#
# Document: 30732, Score: 0.32504206895828247
# -----------
# No access to toilet toilet !!!!!!
# -----------
#
# Document: 22330, Score: 0.3249860107898712
# -----------
# Awesome rubby soap knob by the fountain sink.
# -----------
#
# Document: 319773, Score: 0.324884295463562
# -----------
#  No toilet in here!
# -----------
#
# Document: 172534, Score: 0.3240457773208618
# -----------
# For me the problem is the toilet.
# -----------
#
# Document: 356076, Score: 0.32402634620666504
# -----------
# Great minus - if you sit outside, it is a disgusting smell from the public trash.
# -----------
#
# Document: 75566, Score: 0.32267510890960693
# -----------
# There is only 1 toilet that cannot be locked …
# -----------
#
# Document: 608, Score: 0.3223845958709717
# -----------
# Amsterdam is a nightmare for going the toilet .
# -----------
#
# Document: 30030, Score: 0.3215363025665283
# -----------
# They were extremely wheelchair friendly with no stairs and had a disabled toilet.
# -----------
#
# Document: 30729, Score: 0.3203394114971161
# -----------
# No access to toilet toilet !!!!!!
# -----------
#
# Document: 153136, Score: 0.32017821073532104
# -----------
# The toilet there was spotless.
# -----------
#
# Document: 224589, Score: 0.3198738396167755
# -----------
# No hand soap in the toilets.
# -----------
#
# Document: 72389, Score: 0.3197234869003296
# -----------
# Beautiful interior, nice service, special toilet.
# -----------
#
# Document: 194411, Score: 0.3193904757499695
# -----------
# Toilet does need a facelift.
# -----------
#
# Document: 224434, Score: 0.3189792335033417
# -----------
# Toilet had a broken tap and no soap.
# -----------
#
# Document: 75620, Score: 0.31795889139175415
# -----------
# Very steep stairs to the toilet, be careful.
# -----------
#
# Document: 469431, Score: 0.316927969455719
# -----------
# The ladies bathroom door lock doesn’t work and they know it.
# -----------
#
# Document: 122683, Score: 0.3168186843395233
# -----------
# Interior is nice, a usable toilet for men/women.
# -----------
#
# Document: 135599, Score: 0.3163078725337982
# -----------
# There was no toilet paper and are located next to the kitchen
# -----------
#
# Document: 80971, Score: 0.3155374526977539
# -----------
# No sink in the male toilet.
# -----------
#
# Document: 137039, Score: 0.31491708755493164
# -----------
# Not wheelchair accessible (toilet!).
# -----------
#
# Document: 129088, Score: 0.3144279718399048
# -----------
# Toilet in basement and only accessible via stairs.
# -----------
#
# Document: 294385, Score: 0.3142339587211609
# -----------
# The toilet is not that nice.
# -----------
#
# Document: 242561, Score: 0.3126339912414551
# -----------
# Toilet would not be wheelchair accessible.
# -----------
#
# Document: 115364, Score: 0.31251609325408936
# -----------
# Toilet door doesn't have a lock at all.
# -----------
#
# Document: 342467, Score: 0.31248795986175537
# -----------
# Deduction only for the toilet fee.
# -----------
#
# Document: 167015, Score: 0.3119468092918396
# -----------
# Before even ordering, had to complain about no soap in men's toilets, but this was quickly fixed by a friendly waitress.
# -----------
#
# Document: 213552, Score: 0.31183040142059326
# -----------
# Toilet also in bad condition …
# -----------
#
# Document: 37179, Score: 0.311807245016098
# -----------
# Steep steps for bathroom facilities
# -----------
#
# Document: 437079, Score: 0.3116670250892639
# -----------
# In the toilet there is no water to wash your hands …
# -----------
#
# Document: 155163, Score: 0.3113906681537628
# -----------
# Soap was pre-roped!
# -----------
#
# Document: 113234, Score: 0.31095635890960693
# -----------
# A little strange "home" toilet.
# -----------
#
# Document: 7728, Score: 0.3102055490016937
# -----------
# No lock in the toilets.
# -----------
#
# Document: 912, Score: 0.3092121481895447
# -----------
#  Little messy also annoying that the toilet is only accessible by stairs.
# -----------
#
# Document: 79367, Score: 0.3091554641723633
# -----------
#  1 tap on the toilet was defective, paper towels were gone.
# -----------
#
# Document: 481020, Score: 0.3083868622779846
# -----------
# Not wheelchair accessible (toilet!).
# -----------
#
# Document: 65559, Score: 0.30791980028152466
# -----------
# Toilet must be completely overhauled.
# -----------
#
# Document: 188604, Score: 0.30749577283859253
# -----------
# An increased threshold on entry and toilet at the …
# -----------
#
# Document: 278782, Score: 0.3067823052406311
# -----------
# Toilet on the first floor.
# -----------
#
# Document: 265801, Score: 0.3065536916255951
# -----------
# The place doesn't have a toilet.
# -----------
#
# Document: 265699, Score: 0.3063444495201111
# -----------
# The toilet seat looked so …
# -----------
#
# Document: 21162, Score: 0.30600085854530334
# -----------
# Not wheelchair accessible (toilet!).
# -----------
#
# Document: 31032, Score: 0.3059244751930237
# -----------
# The toilet doors are considerably understickered.
# -----------
#
# Document: 44311, Score: 0.30510738492012024
# -----------
# The deduction is only for the toilet.
# -----------
#
# Document: 347073, Score: 0.30509114265441895
# -----------
# Smells like a toilet!
# -----------
#
# Document: 371954, Score: 0.30499696731567383
# -----------
# Especially when we visited the toilet before ordering ... …
# -----------
#
# Document: 194295, Score: 0.3045397698879242
# -----------
# Friendly service, everything on one floor, wheelchair friendly doors when you open them.
# -----------
#
# Document: 234608, Score: 0.30448251962661743
# -----------
# The bathrooms need an upgrade.
# -----------
#
# Document: 185376, Score: 0.303996741771698
# -----------
# Toilets bordering on indecency there is no sink to wash your hands.
# -----------
#
# Document: 263521, Score: 0.30386561155319214
# -----------
#  Unfortunately no disabled toilet😔😔 very disappointing that these things (wheelchair accessibility and disabled toilet) are still not taken for granted in 2020 !!
# -----------
#
# Document: 181447, Score: 0.3032967448234558
# -----------
# No toilet paper on either toilet, would maybe have given three stars otherwise.
# -----------
#
# Document: 72602, Score: 0.3030602037906647
# -----------
#  Had a wonderful lunch, toilet not wheelchair agile.
# -----------
#
# Document: 264294, Score: 0.3030208349227905
# -----------
# Deduction only for the toilet fee.
# -----------
#
# Document: 147334, Score: 0.3028241693973541
# -----------
#  A minor downside toilet is downstairs and no handrail.
# -----------
#
# Document: 129134, Score: 0.30258387327194214
# -----------
# A minus, for the toilet you have to go down a flight of stairs.
# -----------
#
# Document: 445063, Score: 0.3025814890861511
# -----------
# And the lock of the toilet blocks.
# -----------
#
# Document: 331335, Score: 0.3016289472579956
# -----------
# Upon asking them for soap/handwash they simply said No.
# -----------
#
# Document: 401073, Score: 0.3014174699783325
# -----------
# Only downside is the toilets are down a steep set of stairs
# -----------
#
# Document: 116666, Score: 0.30136197805404663
# -----------
#  Could use the toilet without consuming anything.
# -----------
#
# Document: 274216, Score: 0.3011731803417206
# -----------
# Wheelchair friendly + disabled toilet !!
# -----------
#
# Document: 229004, Score: 0.3011718988418579
# -----------
# They also have a toilet!
# -----------
#
# Document: 80972, Score: 0.30081313848495483
# -----------
# I tried to wash my hands in female's.
# -----------
#
# Document: 165972, Score: 0.29990798234939575
# -----------
# Also the toilet is excessively small.
# -----------
#
# Document: 229031, Score: 0.2998628616333008
# -----------
# You can also go to the toilet.
# -----------
#
# Document: 428117, Score: 0.29982873797416687
# -----------
# Going to the toilet is still an adventure as the stairs go down steeply.
# -----------
#
# Document: 438409, Score: 0.299807071685791
# -----------
# Not wheelchair accessible though as the bathroom is upstairs.
# -----------
#
# Document: 30934, Score: 0.29946839809417725
# -----------
# Quiet location, with access to the classic steep stairs of the place, can hold less than twenty people in …
# -----------
#
# Document: 86954, Score: 0.2985013425350189
# -----------
# Doesn't have a toilet though
# -----------
#
# Document: 457956, Score: 0.29839736223220825
# -----------
# The only thing that sucked was that we could smell the toilet.
# -----------
#
# Document: 365637, Score: 0.2973713278770447
# -----------
# I’ve been throwing up and using the bathroom since 10:45PM last night.
# -----------
#
# Document: 399706, Score: 0.2972050905227661
# -----------
# Despite an unpleasant smell from the drain or toilet, the service was ok, we were quickly found a table.
# -----------
#
# Document: 249340, Score: 0.29678529500961304
# -----------
# Water cocoa for 3.50 in a paper cup.
# -----------
#
# Document: 444951, Score: 0.29646873474121094
# -----------
# Only thing missing in this place is toilet facilities.
# -----------
#
# Document: 450587, Score: 0.29583531618118286
# -----------
# Though the bathroom door is design only for strong women and normal men 💪
# -----------
#
# Document: 154089, Score: 0.2957881689071655
# -----------
# Wheelchairs can be used, but after that there is no disabled toilet.
# -----------
#
# Document: 57416, Score: 0.29558634757995605
# -----------
# Only the toilets are in dire need of a makeover.
# -----------
#
# Document: 227246, Score: 0.29461443424224854
# -----------
# My wheelchair did not fit.
# -----------
#
# Document: 307715, Score: 0.29410406947135925
# -----------
# And a super cool toilet
# -----------
#
# Document: 21777, Score: 0.2934879958629608
# -----------
# Then lock your door!
# -----------
#
# Document: 168530, Score: 0.2934771180152893
# -----------
# My sweet sour sauce tasted like soap.
# -----------
#
# Document: 36768, Score: 0.29337283968925476
# -----------
# The toilet door being right off the bar area was a bit strange...
# -----------
#
# Document: 391895, Score: 0.293195903301239
# -----------
# Found it in the toilet
# -----------
#
# Document: 465352, Score: 0.2930128574371338
# -----------
# What a c * t tent and toilet lady.
# -----------
#
# Document: 438974, Score: 0.2926993668079376
# -----------
# Accessible entrance, and bathrooms/WC on the same floor.
# -----------
#
# Document: 106108, Score: 0.29252660274505615
# -----------
# Inside, I found a nervous lady throwing objects.
# -----------
#
# Document: 104363, Score: 0.29245030879974365
# -----------
#  A visit to the toilet of a special kind.
# -----------
#
# Document: 477992, Score: 0.29220491647720337
# -----------
# Beer with a taste of soap, yummy...
# -----------
#
# Document: 128997, Score: 0.2921905517578125
# -----------
# You have to go down the stairs for the toilet.
# -----------
#
# Document: 135609, Score: 0.2919202148914337
# -----------
# Two stars less because the toilet was disgusting.
# -----------
#
# Document: 173104, Score: 0.2919130325317383
# -----------
# The toilet is in the basement (not bad) …
# -----------
#
# Document: 63766, Score: 0.29177582263946533
# -----------
# Only in the men's toilet there is no real toilet, you have to be content with the women's toilet …
# -----------
#
# Document: 324154, Score: 0.29168587923049927
# -----------
# Unfortunately no toilet for customers …
# -----------
#
# Document: 379433, Score: 0.29084065556526184
# -----------
# The toilet was not too fresh anymore, accessible via a steep staircase.
# -----------
#
# Document: 171404, Score: 0.2902708947658539
# -----------
#  Steak was perfect medium, staff are neat and wash their hands after a toilet visit with soap (the men's altans).
# -----------
#
# Document: 314754, Score: 0.29015684127807617
# -----------
# You can also go to the toilet here.
# -----------
#
# Document: 89206, Score: 0.28976815938949585
# -----------
# A down side is toilet staff.
# -----------
#
# Document: 24662, Score: 0.2896338105201721
# -----------
# 1 star less because toilet is upstairs.
# -----------
#
# Document: 370, Score: 0.2892121970653534
# -----------
# Wheelchair-friendly entrance and …
# -----------
#
# Document: 88543, Score: 0.2889346480369568
# -----------
# Couzy environment, nice bathrooms.
# -----------
#
# Document: 54126, Score: 0.2884969711303711
# -----------
# Even if you order take-away coffee you cannot use the toilet in this place.
# -----------
#
# Document: 378714, Score: 0.2884238064289093
# -----------
# Would have been 4 stars but only restroom for place had no soap or towels.
# -----------
#
# Document: 275500, Score: 0.28833580017089844
# -----------
# Steep stairs to the toilets in the basement.
# -----------
#
# Document: 153996, Score: 0.28829383850097656
# -----------
# 3 times disappointed that they didn't have something and the paper towels near the toilet were also used up.
# -----------
#
# Document: 235730, Score: 0.28826770186424255
# -----------
# There is also a toilet.
# -----------
#
# Document: 371952, Score: 0.28810346126556396
# -----------
#  Service .. food ... toilet ... less than 1 star.
# -----------
#
# Document: 139956, Score: 0.2874298095703125
# -----------
# Beware of the sink in the men's bathroom.
# -----------
#
# Document: 468500, Score: 0.2874252200126648
# -----------
# bouncers - nice, bartender - nice, the toilet "lady"- a looot of attitude problems.
# -----------
#
# Document: 26834, Score: 0.287156879901886
# -----------
# Access to the café by stairs (not aware of an elevator)
# -----------
#
# Document: 104172, Score: 0.2863317131996155
# -----------
# The staffs in the basement toilet is impolite and rude.
# -----------
#
# Document: 104247, Score: 0.28598493337631226
# -----------
# It is a pity that as a customer you stand in line at the toilet for pins because that is also public.
# -----------
#
# Document: 216653, Score: 0.285757839679718
# -----------
# 10 euro entrance fee is a bit steep though, especially since the drinks are not quite affordable either.
# -----------
#
# Document: 347527, Score: 0.28571179509162903
# -----------
# Nice extra feature is that they have music in the toilet.
# -----------
#
# Document: 60155, Score: 0.28568264842033386
# -----------
# Just eat before using the toilet, because they are gross :/
# -----------
#
# Document: 417345, Score: 0.28435492515563965
# -----------
# No water in the toilet for washing hands …
# -----------
#
# Document: 407642, Score: 0.2835659682750702
# -----------
# Up a very steep flight of stairs and into a cozy room with four tables and dozens of teapots hanging from the ceiling.
# -----------
#
# Document: 44786, Score: 0.28353816270828247
# -----------
# Toilet located in the Underworld …
# -----------
#
# Document: 331738, Score: 0.2833694815635681
# -----------
#  Very nice not so big building, beautiful toilet and the place where you can wash your hands!
# -----------
#
# Document: 167280, Score: 0.28327053785324097
# -----------
# Make sure you go to the toilet in advance, because the toilet there (at least for the men) is very tight and …
# -----------
#
# Document: 295857, Score: 0.2832661271095276
# -----------
# I even witness restaurant staff negating access to the toilet to a little girl (maybe 5y.o) as they thought she wasn’t a restaurant guest!
# -----------
#
# Document: 29746, Score: 0.28317633271217346
# -----------
# Attention: The stairs to the toilet are very steep 😉.
# -----------
#
# Document: 308158, Score: 0.2830626368522644
# -----------
# It's not accesible for wheelchair users.
# -----------
#
# Document: 414970, Score: 0.2830239534378052
# -----------
# There was also a great toilet.
# -----------
#
# Document: 84639, Score: 0.282987117767334
# -----------
# Minus two stars because I recognised a cook not washing his hands after toilet.
# -----------
#
# Document: 414251, Score: 0.2828497290611267
# -----------
# Friendly service, everything on one floor, wheelchair friendly doors when you open them.
# -----------
#
# Document: 198456, Score: 0.2828128933906555
# -----------
# Couldn't go to the toilet.
# -----------
#
# Document: 216282, Score: 0.28252941370010376
# -----------
# they have paper straws so also environmentally friendly …
# -----------
#
# Document: 319545, Score: 0.28234127163887024
# -----------
# Toilet becomes difficult for wheelchair users.
# -----------
#
# Document: 5160, Score: 0.2822074592113495
# -----------
# Clam chowder is not good and served in a paper cup.
# -----------
#
# Document: 5841, Score: 0.2820034623146057
# -----------
#  A visit to the toilet of a special kind.
# -----------
#
# Document: 104248, Score: 0.2819482088088989
# -----------
# Toilet wasn't exactly fresh either.
# -----------
#
# Document: 359034, Score: 0.2813218832015991
# -----------
# Unfortunately not much space and no toilet.
# -----------
#
# Document: 306966, Score: 0.2809237241744995
# -----------
# Really disgusting toilets I would prefer a train toilet or the one on trainstations .
# -----------
#
# Document: 363848, Score: 0.2809034287929535
# -----------
# In a time when everyone is taking precautions you are still using your hands to add ice to a drink, the hand dryer doesn’t work in one of the toilets and no hot water to wash ones hands!
# -----------
#
# Document: 7776, Score: 0.28075307607650757
# -----------
# Such a huge company and there’s no TOILET .
# -----------
#
# Document: 397470, Score: 0.28069591522216797
# -----------
# But the stairs to the toilet are a real challenge.
# -----------
#
# Document: 385829, Score: 0.2804924547672272
# -----------
# Toilets are dubious but free!
# -----------
#
# Document: 89089, Score: 0.280464768409729
# -----------
# Toilet was not working well.
# -----------
#
# Document: 453101, Score: 0.2803514003753662
# -----------
# Also the bathroom was spotless.
# -----------
#
# Document: 45152, Score: 0.2802078127861023
# -----------
# Access to the café by stairs (not aware of an elevator)
# -----------
#
# Document: 425928, Score: 0.28002285957336426
# -----------
# Just remember to ask for "no cilantro" if you think it tastes like soap.
# -----------
#
# Document: 428114, Score: 0.27994638681411743
# -----------
# Going to the toilet is still an adventure as the stairs go down steeply.
# -----------
#
# Document: 100278, Score: 0.27945464849472046
# -----------
# He is using a wheelchair, and there is no table suited for him..  all the tables on the main level are bar high, and to get to "normal" table will be impossible for him, as there are 3 big steps to climb..  too bad :(
# -----------
#
# Document: 335239, Score: 0.2793408930301666
# -----------
# Unfortunately there was no hand soap, or hand sanitizer.
# -----------
#
# Document: 90521, Score: 0.2789372205734253
# -----------
# Badest toilet facilities ever (1 for gents and girls, on a total capacity of 250 pax).
# -----------
#
# Document: 479061, Score: 0.27891531586647034
# -----------
# We asked for paper towels to mop up the spill and she …
# -----------
#
# Document: 408308, Score: 0.2789110839366913
# -----------
# Be careful when the stairs are so steep.
# -----------
#
# Document: 392875, Score: 0.2788531184196472
# -----------
# My aunt have left her phone at the toilet and they hold on until and we are back .
# -----------
#
# Document: 367292, Score: 0.27867740392684937
# -----------
# Ok so I really liked the alignment of colors of the men's bathroom.
# -----------
#
# Document: 139236, Score: 0.2786025106906891
# -----------
# What I do not understand is that the toilet is closed.
# -----------
#
# Document: 19389, Score: 0.278411865234375
# -----------
# Paper with hint of meat.
# -----------
#
# Document: 119206, Score: 0.2782764434814453
# -----------
# Stairs to toilets are narrow and steep.
# -----------
#
# Document: 138211, Score: 0.2782372534275055
# -----------
# Didn't have any toilet paper and after asking the guys at the counter they said no toilet paper.
# -----------
#
# Document: 264969, Score: 0.2782217562198639
# -----------
# Interior is nice, a usable toilet for men/women.
# -----------
#
# Document: 201715, Score: 0.2781388461589813
# -----------
# Very nice plase,tasty club sandwitch,coffee,all nice,toilet,free wifi.
# -----------
#
# Document: 5638, Score: 0.2780765891075134
# -----------
# Very interesting foggy doors bathroom system :)
# -----------
#
# Document: 359910, Score: 0.27803853154182434
# -----------
# For some strange reason when they wash ashore they empty the bucket into the …
# -----------
#
# Document: 324208, Score: 0.27737003564834595
# -----------
# There is just not that much seating space and no toilet.
# -----------
#
# Document: 465432, Score: 0.2773566246032715
# -----------
# Please check out the toilet!
# -----------
#
# Document: 3006, Score: 0.27723583579063416
# -----------
# Nice toilet / jacket lady!
# -----------
#
# Document: 171181, Score: 0.27703046798706055
# -----------
# Always provide crayons and a drawing paper for my toddler.
# -----------
#
# Document: 5557, Score: 0.276978999376297
# -----------
# But you can visit toilet only once for free.
# -----------
#
# Document: 72130, Score: 0.27694985270500183
# -----------
# The toilet is also worth a visit with a …
# -----------
#
# Document: 271957, Score: 0.276904433965683
# -----------
# Toilet on the top of some steps.
# -----------
#
# Document: 263578, Score: 0.2768254578113556
# -----------
# But it suddenly seems to be 10, chalked on a paper plate at the entrance, so unfortunately.
# -----------
#
# Document: 469622, Score: 0.27678513526916504
# -----------
# Smells like toilet half of the time.
# -----------
#
# Document: 69019, Score: 0.2767823040485382
# -----------
# Drinks served in paper cups served by a real moody lady.
# -----------
#
# Document: 194057, Score: 0.27671390771865845
# -----------
# Cloth served and environmentally friendly hand soap.
# -----------
#
# Document: 96756, Score: 0.27662044763565063
# -----------
# Wouldn't have been here if it wasn't to use the toilet there.
# -----------
#
# Document: 49291, Score: 0.2763035297393799
# -----------
# There was just a weird scribble on the mirror in the toilet.
# -----------
#
# Document: 294911, Score: 0.2762594223022461
# -----------
# Apart from the mold on the toilet paper and further rancidity in the "restaurant", especially the food was just bad.
# -----------
#
# Document: 391980, Score: 0.2762535810470581
# -----------
# Toilets neat and wheelchair friendly.
# -----------
#
# Document: 449171, Score: 0.2760275602340698
# -----------
#  Why is there no toilet for someone in a wheelchair.
# -----------
#
# Document: 190225, Score: 0.276011198759079
# -----------
# Toilet was not very fresh unfortunately.
# -----------
#
# Document: 144955, Score: 0.275795042514801
# -----------
# a pungent smell came from the basement where the toilet is, which did not stimulate the appetite to eat …
# -----------
#
# Document: 226649, Score: 0.2757247984409332
# -----------
# Chilled space - no toilet??????
# -----------
#
# Document: 414643, Score: 0.2757169008255005
# -----------
# The food is gross, huge quantity but low quality, the ink fish was gummy, the soups smelled like dish soap and none of the staff was thai.
# -----------

# %%
print(relevant_docs)
# Out:
# [(79940, 0.3964807987213135, 'Toilets without toilet paper and soap.'), (29464, 0.3883405923843384, "The toilets didn't have soap or paper towels."), (386279, 0.37139904499053955, 'The toilet is old and leaking.'), (158339, 0.3659678101539612, '(Only in the hallway to the toilet).'), (266475, 0.36508306860923767, "The men's bathrooms had no functioning lock."), (313227, 0.3647236227989197, 'The male bathroom could use a lock.'), (453437, 0.3627600073814392, "Bathroom without soap and towels, so one can't either wash its hands."), (135856, 0.3621731698513031, 'Warm, cozy, toilet.'), (44626, 0.3620632588863373, 'No toilet paper for women.'), (90512, 0.3610458970069885, 'No soap in the bathroom either.'), (313036, 0.35660603642463684, "The toilet didn't have a lock."), (201903, 0.35598379373550415, "I go to the bathroom and I can't find toilet paper, much less a sink to wash my hands .. That is, I wonder how it is possible …"), (128454, 0.35471636056900024, 'Toilet unfortunately not wheelchair accessible (down …'), (117142, 0.3542335033416748, 'Love the modern interior and Rituals soap and hand lotion in the bathrooms :)'), (379412, 0.3528940677642822, 'and leftover toilet paper!'), (157765, 0.35123544931411743, 'Toilet was clogged and smelly.'), (363930, 0.347439169883728, " With King's Day a bad experience that as a lady you cannot go to the men's toilet because it takes too long for the ladies to empty your stoma in the toilet."), (266809, 0.34590959548950195, 'No soap and hand paper on the toilet …'), (211964, 0.3437686860561371, 'Toilet paper was diffidently absorbent.'), (224846, 0.343313068151474, 'No toilet is a downside.'), (461823, 0.342890202999115, ' No toilet that is accessible for the disabled anymore, also the side door / gate was not opened for wheelchair access.'), (265980, 0.34278666973114014, 'Seen one kitchen staff washing his hands without any soap after using toilets..'), (358931, 0.3427804112434387, 'There is no toilet!'), (35281, 0.341844767332077, 'Unfortunately the toilet is down the stairs so not wheelchair accessible.'), (353, 0.34170323610305786, 'No toilet paper in toilet.'), (482365, 0.3399185240268707, 'No soap in the bathroom.'), (126571, 0.33539092540740967, 'Nice people, and a very nice toilet.'), (359976, 0.3351364731788635, 'Toilet was clogged and smelly.'), (304628, 0.3347105383872986, 'The toilets where unacceptably bad for such a high end restaurant there was no soap or towels and the …'), (310992, 0.33411094546318054, 'The toilet doors are considerably understickered.'), (7774, 0.3325188159942627, 'Combination of bad experiences here, capped by a poor toilet experience : no toilet paper, urine on the floors, and no soap.'), (135585, 0.3312130570411682, 'The Polish waiter said I cannot use the toilet …'), (27288, 0.32861989736557007, 'Toilet would not be wheelchair accessible.'), (134600, 0.32844752073287964, 'and the soap of the dan it was amazing!'), (22272, 0.32831770181655884, 'Staff also use this toilet ... you can check what is in your food if they do not wash their hands with soap .... …'), (142757, 0.3273043632507324, "Beware of the sink in the men's bathroom."), (209823, 0.3261016607284546, " With King's Day a bad experience that as a lady you cannot go to the men's toilet because it takes too long for the ladies to empty your stoma in the toilet."), (237848, 0.32595595717430115, 'No towels in the toilet either.'), (30732, 0.32504206895828247, 'No access to toilet toilet !!!!!!'), (22330, 0.3249860107898712, 'Awesome rubby soap knob by the fountain sink.'), (319773, 0.324884295463562, ' No toilet in here!'), (172534, 0.3240457773208618, 'For me the problem is the toilet.'), (356076, 0.32402634620666504, 'Great minus - if you sit outside, it is a disgusting smell from the public trash.'), (75566, 0.32267510890960693, 'There is only 1 toilet that cannot be locked …'), (608, 0.3223845958709717, 'Amsterdam is a nightmare for going the toilet .'), (30030, 0.3215363025665283, 'They were  ...

# %%
# Reset the index of the dataframe
split_google_reviews = split_google_reviews.reset_index(drop=True)

# %%
relevant_ids = [document[0] for document in relevant_docs]
filtered_reviews = split_google_reviews[split_google_reviews.index.isin(relevant_ids)]

# %%
filtered_reviews.to_csv(home_path + 'data/processed/aspect_classification_data/filtered_new_toilets_google_reviews.csv', index=False)

# %% [markdown]
# Join all data together

# %%
access_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_access_google_reviews.csv')
toilet_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_toilet_google_reviews.csv')
noise_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_noise_google_reviews.csv')
staff_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_staff_google_reviews.csv')
entrance_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_entrance_google_reviews.csv')
parking_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_parking_google_reviews.csv')
wheelchair_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_wheelchair_google_reviews.csv')
transport_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_transport_google_reviews.csv')

# %%
concatenated_sample = pd.concat([access_reviews, toilet_reviews, noise_reviews, staff_reviews, entrance_reviews, parking_reviews, wheelchair_reviews, transport_reviews], ignore_index=True)

# %%
len(concatenated_sample)
# Out:
# 1601

# %%
concatenated_sample.drop_duplicates(subset=["Sentences"], inplace=True)

# %%
len(concatenated_sample)
# Out:
# 1307

# %%
other_reviews = pd.read_csv(home_path + 'data/processed/aspect_classification_data/filtered_other_google_reviews.csv')
full_concatenated_sample = pd.concat([concatenated_sample, other_reviews], ignore_index=True)

# %%
full_concatenated_sample.drop_duplicates(subset=["Sentences"], inplace=True)

# %%
len(other_reviews)
# Out:
# 1100

# %%
full_concatenated_sample.to_excel(home_path + 'data/processed/aspect_classification_data/full_concatenated_google_reviews.xlsx', index=False)
